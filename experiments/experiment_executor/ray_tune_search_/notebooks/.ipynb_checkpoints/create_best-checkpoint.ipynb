# %%
def read_csv(dataset,type_simclr,n_transformations,percentage,dir):
    
    try:
        if(n_transformations>-1):
            folder=f'../{dir}{type_simclr}/{dataset}/'
            folder_percentage=f'{type_simclr}_{n_transformations}T_{dataset}_P{percentage}/data.csv'
        else:
            folder=f'../{dir}/{dataset}/'
            folder_percentage=f'{type_simclr}_{dataset}_P{percentage}/data.csv'
            #print('n_transformations',n_transformations)
            
        
        data = pd.read_csv(f'{folder}{folder_percentage}')
        data.loc[data['score'] < 0,'score'] = 0
    except:
        print(f'{folder}{folder_percentage}')
    
        data = pd.DataFrame({'Unnamed: 0': [], 'score': []})
    return data

# %%
import yaml
import pandas as pd
import pandas as pd
datasets = ['kuhar', 'motionsense', 'uci', 'wisdm', 'realworld_thigh', 'realworld_waist']
#datasets = [ 'uci']

models=['simclr_linear']
percentages=[25, 50, 75, 100, 200]
n_transformations_list=[1,2,3,4]
def get_max_by_each_transformation():
    dir="experiments/simclr_all/by_n_transformations/"
    
    df_maximas = pd.DataFrame() 
    for dataset in datasets:       
            for i, percentage in enumerate(percentages):
                for n_transformations in n_transformations_list:
                    max_length = 0
                    for j, model in enumerate(models):
                        try:
                            data = read_csv(dataset, model, n_transformations, percentage,dir)
                            max_dataset_score = data['score'].max()
                            indice_maximo = data['score'].idxmax()
                            fila_maxima = data.loc[indice_maximo].copy()  # Create a copy to avoid SettingWithCopyWarning
                            fila_maxima['percentage']=percentage
                            fila_maxima['n_transformations']=n_transformations
                            fila_maxima['dir']=str(dir)
                            fila_maxima['dataset']=dataset
                            fila_maxima['model']=model
                            fila_maxima['test']='sep_transf'

                            df_maximas = pd.concat([df_maximas, fila_maxima.to_frame().T], ignore_index=True)
    
                        except:
                            e=1
    return df_maximas
           

df_each_tranf=get_max_by_each_transformation()
    
    
                   
df_each_tranf
# Out:
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_2T_wisdm_P25/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_3T_wisdm_P25/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_4T_wisdm_P25/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_2T_wisdm_P50/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_3T_wisdm_P50/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_4T_wisdm_P50/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_2T_wisdm_P75/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_3T_wisdm_P75/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_4T_wisdm_P75/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_2T_wisdm_P100/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_3T_wisdm_P100/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_4T_wisdm_P100/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_1T_wisdm_P200/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_2T_wisdm_P200/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_3T_wisdm_P200/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/wisdm/simclr_full_4T_wisdm_P200/data.csv
# ../experiments/simclr_all/by_n_transformations/simclr_full/realworld_waist/simclr_full_4T_realworld_waist_P200/data.csv
#     Unnamed: 0     score randomforest-100-accuracy (mean)  \
# 0          627  0.668075                         0.668075
# 1          613  0.692254                         0.692254
# 2          460  0.662676                         0.662676
# 3          945  0.678404                         0.668075
# 4         1109  0.689671                         0.689671
# ..         ...       ...                              ...
# 98        1107  0.891046                         0.825728
# 99         877   0.88781                         0.859008
# 100       1364  0.875944                         0.838781
# 101       1954  0.882956                          0.85329
# 102       1209   0.88781                         0.863053
#
#     randomforest-100-accuracy (std) randomforest-100-f1-score macro (mean)  \
# 0                            0.0046                               0.664285
# 1                           0.00625                               0.692089
# 2                          0.010017                               0.661632
# 3                          0.004834                               0.670715
# 4                          0.008319                                0.69409
# ..                              ...                                    ...
# 98                         0.009294                               0.823782
# 99                         0.002645                               0.857603
# 100                        0.002569                               0.837006
# 101                        0.002326                               0.850839
# 102                        0.002636                                0.86101
#
#     randomforest-100-f1-score macro (std)  \
# 0                                0.004307
# 1                                0.005891
# 2                                0.009421
# 3                                0.004575
# 4                                0.008008
# ..                                    ...
# 98                               0.009737
# 99                               0.002639
# 100                              0.002523
# 101                              0.002277
# 102                              0.002581
#
#     randomforest-100-f1-score weighted (mean)  \
# 0                                    0.664285
# 1                                    0.692089
# 2                                    0.661632
# 3                                    0.670715
# 4                                     0.69409
# ..                                        ...
# 98                                   0.823782
# 99                                   0.857603
# 100                                  0.837006
# 101                                  0.850839
# 102                                   0.86101
#
#     randomforest-100-f1-score weighted (std) KNN-5-accuracy (mean)  \
# 0                                   0.004307              0.622066
# 1                                   0.005891              0.673709
# 2                                   0.009421              0.612676
# 3                                   0.004575              0.678404
# 4                                   0.008008              0.650235
# ..                                       ...                   ...
# 98                                  0.009737              0.812298
# 99                                  0.002639              0.843042
# 100                                 0.002523              0.832794
# 101                                 0.002277              0.870011
# 102                                 0.002581               0.83603
#
#     KNN-5-accuracy (std)  ... n_transformations  \
# 0                    0.0  ...                 1
# 1                    0.0  ...                 2
# 2                    0.0  ...                 3
# 3                    0.0  ...                 4
# 4                    0.0  ...                 1
# ..                   ...  ...               ...
# 98                   0.0  ...                 3
# 99                   0.0  ...                 4
# 100                  0.0  ...                 1
# 101                  0.0  ...                 2
# 102                  0.0  ...                 3
#
#                                               dir          dataset  \
# 0    experiments/simclr_all/by_n_transformations/            kuhar
# 1    experiments/simclr_all/by_n_transformations/            kuhar
# 2    experiments/simclr_all/by_n_transformations/            kuhar
# 3    experiments/simclr_all/by_n_transformations/            kuhar
# 4    experiments/simclr_all/by_n_transformations/            kuhar
# ..                                            ...              ...
# 98   experiments/simclr_all/by_n_transformations/  realworld_waist
# 99   experiments/simclr_all/by_n_transformations/  realworld_waist
# 100  experiments/simclr_all/by_n_transformations/  realworld_waist
# 101  experiments/simclr_all/by_n_transformations/  realworld_waist
# 102  experiments/simclr_all/by_n_transformations/  realworld_waist
#
#            model        test num_params num_trainable_params error_type  \
# 0    simclr_full  sep_transf        NaN                  NaN        NaN
# 1    simclr_full  sep_transf        NaN                  NaN        NaN
# 2    simclr_full  sep_transf        NaN                  NaN        NaN
# 3    simclr_full  sep_transf        NaN                  NaN        NaN
# 4    simclr_full  sep_transf        NaN                  NaN        NaN
# ..           ...         ...        ...                  ...        ...
# 98   simclr_full  sep_transf        NaN                  NaN        NaN
# 99   simclr_full  sep_transf        NaN                  NaN        NaN
# 100  simclr_full  sep_transf        NaN                  NaN        NaN
# 101  simclr_full  sep_transf        NaN                  NaN        NaN
# 102  simclr_full  sep_transf        NaN                  NaN        NaN
#
#     error_message error_traceback
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
# ..            ...             ...
# 98            NaN             NaN
# 99            NaN             NaN
# 100           NaN             NaN
# 101           NaN             NaN
# 102           NaN             NaN
#
# [103 rows x 49 columns]

# %%
def get_max_all_transf():
    test_list=['tem_transf']
    #test_list=['tem_transf']
    df_maximas = pd.DataFrame()       
    for dataset in datasets:           
            for i, percentage in enumerate(percentages):
             for model in models:
                for test in test_list:
                    dir=f'experiments/simclr_all/all_transformations/{model}/{test}'
    
                    try:                
                        n_transformations=-1
                        data = read_csv(dataset, model, n_transformations, percentage,dir)
                        max_dataset_score = data['score'].max()
                        indice_maximo = data['score'].idxmax()
                        fila_maxima = data.loc[indice_maximo].copy()  # Create a copy to avoid SettingWithCopyWarning
                        fila_maxima['percentage']=percentage
                        fila_maxima['n_transformations']=n_transformations
                        fila_maxima['dir']=str(dir)
                        fila_maxima['dataset']=dataset
                        fila_maxima['model']=model  
                        fila_maxima['test']=test
                        
                        df_maximas = pd.concat([df_maximas, fila_maxima.to_frame().T], ignore_index=True)
                   
                    except:
                       e=1
    return df_maximas
df_all_tf=get_max_all_transf()
df_all_tf
# Out:
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/wisdm/simclr_full_wisdm_P50/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_thigh/simclr_full_realworld_thigh_P25/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_thigh/simclr_full_realworld_thigh_P50/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_thigh/simclr_full_realworld_thigh_P75/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_thigh/simclr_full_realworld_thigh_P100/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_thigh/simclr_full_realworld_thigh_P200/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_waist/simclr_full_realworld_waist_P25/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_waist/simclr_full_realworld_waist_P50/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_waist/simclr_full_realworld_waist_P75/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_waist/simclr_full_realworld_waist_P100/data.csv
# ../experiments/simclr_all/all_transformations/simclr_full/tem_transf/realworld_waist/simclr_full_realworld_waist_P200/data.csv
#    Unnamed: 0     score randomforest-100-accuracy (mean)  \
# 0         854  0.748357                         0.748357
# 1         899  0.726291                         0.726291
# 2         307  0.707981                         0.707981
# 3         804  0.723944                         0.723944
# 4         158  0.703521                         0.703521
# 5         956  0.869048                         0.845476
# 6          78  0.861905                         0.839524
# 7         614  0.870952                         0.870952
# 8         407  0.860952                         0.860952
# 9         796  0.875714                         0.875714
# 10        593       0.9                         0.887941
# 11        176  0.905882                         0.885882
# 12        407  0.904706                         0.904706
# 13        638  0.909412                         0.909412
# 14        724     0.905                            0.905
# 15          0       0.0                              NaN
# 16          0       0.0                              NaN
# 17          0       0.0                              NaN
# 18          0       0.0                              NaN
#
#    randomforest-100-accuracy (std) randomforest-100-f1-score macro (mean)  \
# 0                         0.004902                               0.742737
# 1                         0.005475                               0.730292
# 2                         0.005769                               0.704897
# 3                         0.005373                               0.714135
# 4                         0.004206                               0.697097
# 5                         0.003757                               0.849725
# 6                         0.002428                               0.843864
# 7                         0.006717                               0.874348
# 8                         0.006227                               0.864377
# 9                         0.006633                               0.878848
# 10                        0.002443                               0.887002
# 11                        0.006281                               0.885486
# 12                        0.004201                               0.904124
# 13                        0.004706                               0.909175
# 14                        0.004566                               0.905295
# 15                             NaN                                    NaN
# 16                             NaN                                    NaN
# 17                             NaN                                    NaN
# 18                             NaN                                    NaN
#
#    randomforest-100-f1-score macro (std)  \
# 0                               0.004766
# 1                               0.005184
# 2                               0.004928
# 3                               0.005686
# 4                               0.004368
# 5                               0.003631
# 6                               0.002423
# 7                               0.006449
# 8                               0.005898
# 9                               0.006295
# 10                              0.002429
# 11                              0.006328
# 12                              0.004276
# 13                              0.004761
# 14                              0.004541
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
#
#    randomforest-100-f1-score weighted (mean)  \
# 0                                   0.742737
# 1                                   0.730292
# 2                                   0.704897
# 3                                   0.714135
# 4                                   0.697097
# 5                                   0.849725
# 6                                   0.843864
# 7                                   0.874348
# 8                                   0.864377
# 9                                   0.878848
# 10                                  0.887002
# 11                                  0.885486
# 12                                  0.904124
# 13                                  0.909175
# 14                                  0.905295
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
#
#    randomforest-100-f1-score weighted (std) KNN-5-accuracy (mean)  \
# 0                                  0.004766              0.720657
# 1                                  0.005184              0.704225
# 2                                  0.004928              0.669014
# 3                                  0.005686              0.687793
# 4                                  0.004368              0.673709
# 5                                  0.003631              0.869048
# 6                                  0.002423              0.861905
# 7                                  0.006449              0.804762
# 8                                  0.005898              0.830952
# 9                                  0.006295              0.816667
# 10                                 0.002429                   0.9
# 11                                 0.006328              0.905882
# 12                                 0.004276              0.891176
# 13                                 0.004761              0.902941
# 14                                 0.004541              0.891176
# 15                                      NaN                   NaN
# 16                                      NaN                   NaN
# 17                                      NaN                   NaN
# 18                                      NaN                   NaN
#
#    KNN-5-accuracy (std)  ... n_transformations  \
# 0                   0.0  ...                -1
# 1                   0.0  ...                -1
# 2                   0.0  ...                -1
# 3                   0.0  ...                -1
# 4                   0.0  ...                -1
# 5                   0.0  ...                -1
# 6                   0.0  ...                -1
# 7                   0.0  ...                -1
# 8                   0.0  ...                -1
# 9                   0.0  ...                -1
# 10                  0.0  ...                -1
# 11                  0.0  ...                -1
# 12                  0.0  ...                -1
# 13                  0.0  ...                -1
# 14                  0.0  ...                -1
# 15                  NaN  ...                -1
# 16                  NaN  ...                -1
# 17                  NaN  ...                -1
# 18                  NaN  ...                -1
#
#                                                   dir      dataset  \
# 0   experiments/simclr_all/all_transformations/sim...        kuhar
# 1   experiments/simclr_all/all_transformations/sim...        kuhar
# 2   experiments/simclr_all/all_transformations/sim...        kuhar
# 3   experiments/simclr_all/all_transformations/sim...        kuhar
# 4   experiments/simclr_all/all_transformations/sim...        kuhar
# 5   experiments/simclr_all/all_transformations/sim...  motionsense
# 6   experiments/simclr_all/all_transformations/sim...  motionsense
# 7   experiments/simclr_all/all_transformations/sim...  motionsense
# 8   experiments/simclr_all/all_transformations/sim...  motionsense
# 9   experiments/simclr_all/all_transformations/sim...  motionsense
# 10  experiments/simclr_all/all_transformations/sim...          uci
# 11  experiments/simclr_all/all_transformations/sim...          uci
# 12  experiments/simclr_all/all_transformations/sim...          uci
# 13  experiments/simclr_all/all_transformations/sim...          uci
# 14  experiments/simclr_all/all_transformations/sim...          uci
# 15  experiments/simclr_all/all_transformations/sim...        wisdm
# 16  experiments/simclr_all/all_transformations/sim...        wisdm
# 17  experiments/simclr_all/all_transformations/sim...        wisdm
# 18  experiments/simclr_all/all_transformations/sim...        wisdm
#
#           model        test num_params num_trainable_params  \
# 0   simclr_full  tem_transf        NaN                  NaN
# 1   simclr_full  tem_transf        NaN                  NaN
# 2   simclr_full  tem_transf        NaN                  NaN
# 3   simclr_full  tem_transf        NaN                  NaN
# 4   simclr_full  tem_transf        NaN                  NaN
# 5   simclr_full  tem_transf        NaN                  NaN
# 6   simclr_full  tem_transf        NaN                  NaN
# 7   simclr_full  tem_transf        NaN                  NaN
# 8   simclr_full  tem_transf        NaN                  NaN
# 9   simclr_full  tem_transf        NaN                  NaN
# 10  simclr_full  tem_transf        NaN                  NaN
# 11  simclr_full  tem_transf        NaN                  NaN
# 12  simclr_full  tem_transf        NaN                  NaN
# 13  simclr_full  tem_transf        NaN                  NaN
# 14  simclr_full  tem_transf        NaN                  NaN
# 15  simclr_full  tem_transf         -1                   -1
# 16  simclr_full  tem_transf         -1                   -1
# 17  simclr_full  tem_transf         -1                   -1
# 18  simclr_full  tem_transf         -1                   -1
#
#                 error_type                                      error_message  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6                      NaN                                                NaN
# 7                      NaN                                                NaN
# 8                      NaN                                                NaN
# 9                      NaN                                                NaN
# 10                     NaN                                                NaN
# 11                     NaN                                                NaN
# 12                     NaN                                                NaN
# 13                     NaN                                                NaN
# 14                     NaN                                                NaN
# 15  <class 'RuntimeError'>  CUDA error: device-side assert triggered\nCUDA...
# 16  <class 'RuntimeError'>  CUDA error: unspecified launch failure\nCUDA k...
# 17  <class 'RuntimeError'>  CUDA error: device-side assert triggered\nCUDA...
# 18  <class 'RuntimeError'>  CUDA error: device-side assert triggered\nCUDA...
#
#                                       error_traceback
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15    File "/home/amparo/unicamp_hyper3/M4-Framewo...
# 16    File "/home/amparo/unicamp_hyper3/M4-Framewo...
# 17    File "/home/amparo/unicamp_hyper3/M4-Framewo...
# 18    File "/home/amparo/unicamp_hyper3/M4-Framewo...
#
# [19 rows x 48 columns]

# %%
maximos_por_grupo = df_each_tranf.groupby(['dataset','model', 'percentage','n_transformations'])['score'].max()
maximos_por_grupo
# Out:
# dataset  model        percentage  n_transformations
# kuhar    simclr_full  25          1                    0.668075
#                                   2                    0.692254
#                                   3                    0.662676
#                                   4                    0.678404
#                       50          1                    0.689671
#                                                          ...
# uci      simclr_full  200         4                    0.891176
# wisdm    simclr_full  25          1                         0.0
#                       50          1                         0.0
#                       75          1                         0.0
#                       100         1                         0.0
# Name: score, Length: 103, dtype: object

# %%
maximos_por_grupo = df_all_tf.groupby(['dataset', 'model','percentage','test'])['score'].max()
maximos_por_grupo
# Out:
# dataset      model        percentage  test
# kuhar        simclr_full  25          tem_transf    0.748357
#                           50          tem_transf    0.726291
#                           75          tem_transf    0.707981
#                           100         tem_transf    0.723944
#                           200         tem_transf    0.703521
# motionsense  simclr_full  25          tem_transf    0.869048
#                           50          tem_transf    0.861905
#                           75          tem_transf    0.870952
#                           100         tem_transf    0.860952
#                           200         tem_transf    0.875714
# uci          simclr_full  25          tem_transf         0.9
#                           50          tem_transf    0.905882
#                           75          tem_transf    0.904706
#                           100         tem_transf    0.909412
#                           200         tem_transf       0.905
# wisdm        simclr_full  25          tem_transf         0.0
#                           75          tem_transf         0.0
#                           100         tem_transf         0.0
#                           200         tem_transf         0.0
# Name: score, dtype: object

# %%
df_all_best=concatenated_df = pd.concat([df_each_tranf, df_all_tf], ignore_index=True)
maximos_por_grupo = df_all_best.groupby(['dataset', 'model','percentage'])['score'].max()
maximos_por_grupo
# Out:
# dataset          model        percentage
# kuhar            simclr_full  25            0.748357
#                               50            0.726291
#                               75            0.707981
#                               100           0.723944
#                               200           0.703521
# motionsense      simclr_full  25            0.882619
#                               50            0.872619
#                               75            0.876905
#                               100           0.892381
#                               200           0.880238
# realworld_thigh  simclr_full  25            0.798753
#                               50            0.798186
#                               75             0.79932
#                               100           0.797052
#                               200           0.797619
# realworld_waist  simclr_full  25             0.89644
#                               50             0.88781
#                               75             0.88835
#                               100           0.891046
#                               200            0.88781
# uci              simclr_full  25            0.907647
#                               50            0.905882
#                               75            0.906471
#                               100           0.909412
#                               200              0.905
# wisdm            simclr_full  25                 0.0
#                               50                 0.0
#                               75                 0.0
#                               100                0.0
#                               200                0.0
# Name: score, dtype: object

# %%
idx_max = df_all_best.groupby(['dataset','model', 'percentage'])['score'].idxmax()
df_fmax_score = df_all_best.loc[idx_max]

combined_data = pd.DataFrame()
for index, row in df_fmax_score.iterrows():
    dataset=row['dataset']
    model=row['model']
    n_transformations=row['n_transformations']
    percentage=row['percentage']
    dir=row['dir']
    data = read_csv(dataset, model, n_transformations, percentage,dir)
    data['dataset'] = dataset
    data['model'] = model
    data['n_transformations'] = n_transformations
    data['percentage'] = percentage
    combined_data = pd.concat([combined_data, data], ignore_index=True)
combined_data.columns
#combined_data.to_csv(f'results_simclr.csv', index=False)
# Out:
# Index(['Unnamed: 0', 'score', 'randomforest-100-accuracy (mean)',
#        'randomforest-100-accuracy (std)',
#        'randomforest-100-f1-score macro (mean)',
#        'randomforest-100-f1-score macro (std)',
#        'randomforest-100-f1-score weighted (mean)',
#        'randomforest-100-f1-score weighted (std)', 'KNN-5-accuracy (mean)',
#        'KNN-5-accuracy (std)', 'KNN-5-f1-score macro (mean)',
#        'KNN-5-f1-score macro (std)', 'KNN-5-f1-score weighted (mean)',
#        'KNN-5-f1-score weighted (std)', 'SVM-rbf-C1.0-accuracy (mean)',
#        'SVM-rbf-C1.0-accuracy (std)', 'SVM-rbf-C1.0-f1-score macro (mean)',
#        'SVM-rbf-C1.0-f1-score macro (std)',
#        'SVM-rbf-C1.0-f1-score weighted (mean)',
#        'SVM-rbf-C1.0-f1-score weighted (std)', 'timestamp', 'done',
#        'training_iteration', 'trial_id', 'date', 'time_this_iter_s',
#        'time_total_s', 'pid', 'hostname', 'node_ip', 'time_since_restore',
#        'iterations_since_restore', 'checkpoint_dir_name',
#        'config/temperature_head', 'config/latent_dim',
#        'config/transform_funcs', 'logdir', 'dataset', 'model',
#        'n_transformations', 'percentage', 'config/batch_size', 'num_params',
#        'num_trainable_params', 'error_type', 'error_message',
#        'error_traceback'],
#       dtype='object')

# %%
def create_folder(folder_name):
    import os
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
        
def create_execute(script_file,script_content):
    script_file.write(script_content)
    
def create_simclr_basic_best(dataset,folder,config):
    data="""
    estimators:
    -   algorithm: RandomForest
        kwargs:
            n_estimators: 100
        name: randomforest-100
        num_runs: 10
    -   algorithm: KNN
        kwargs:
            n_neighbors: 5
        name: KNN-5
        num_runs: 1
    -   algorithm: SVM
        kwargs:
            C: 1.0
            kernel: rbf
        name: SVM-rbf-C1.0
        num_runs: 1
    extra:
        in_use_features:
        - accel-x
        - accel-y
        - accel-z
        - gyro-x
        - gyro-y
        - gyro-z
        reduce_on: all
        save_reducer: true
        scale_on: train
    reducer:
        algorithm: SimCLR
        kwargs:
            input_shape: [60, 6]
            n_components: 98
            batch_size: 256
            transform_funcs: [0]
            temperature: 1.0
            epochs: 300
            verbose: 0
            patience: 10
            min_delta: 0.001
            device: 'cuda'
            dataset: 'uci'
            save_reducer: false
            
        name: SIMCLR
        use_y: false
    
    reducer_dataset:
    - uci.standartized_balanced[train]
    test_dataset:
    - uci.standartized_balanced[validation]
    train_dataset:
    - uci.standartized_balanced[train]
    
    
    
    version: '1.0'
    """
    transform = [int(caracter) for caracter in config['transform_funcs'] if caracter.isdigit()]
    config_data = data.replace('transform_funcs: [0]',f'transform_funcs: {transform}')
    config_data = config_data.replace('uci',f'{dataset}')

    with open(f'{folder}/base_config.yaml', 'w') as file:
            file.write(config_data)

def create_exploration_config_simclr_best(folder,latent_dim):
    data= """
    resources:
      gpu: 0.9
      cpu: 1.0
    search_space: 
    
      min_delta:
        tune_function: quniform
        tune_parameters: [0.001, 0.9,0.001]
        route: reducer/kwargs/min_delta
    
     temperature_head:
        tune_function: quniform
        tune_parameters: [0.1, 1.0,0.1]
        route: reducer/kwargs/temperature_head
    
      latent_dim:
        tune_function: randint
        tune_parameters: [2,361.0]
        route: reducer/kwargs/n_components
    
    
      batch_size:
        tune_function: randint
        tune_parameters: [128, 512]
        route: reducer/kwargs/batch_size
    
    initial_params:
    
    """
    dim=str((latent_dim*360/100)+1)
    config_data = data.replace('tune_parameters: [2, 361]',f'tune_parameters: [2,{dim}]')
    with open(f'{folder}/exploration_config.yaml', 'w') as file:
        file.write(config_data)




def create_simclr_full_basic_best(dataset,folder,config):
    data="""
estimators:
- algorithm: RandomForest
  kwargs:
    n_estimators: 100
  name: randomforest-100
  num_runs: 10
- algorithm: KNN
  kwargs:
    n_neighbors: 5
  name: KNN-5
  num_runs: 1
- algorithm: SVM
  kwargs:
    C: 1.0
    kernel: rbf
  name: SVM-rbf-C1.0
  num_runs: 1
extra:
  in_use_features:
  - accel-x
  - accel-y
  - accel-z
  - gyro-x
  - gyro-y
  - gyro-z
  reduce_on: all
  save_reducer: false
  scale_on: train
reducer:
  algorithm: SimCLR_full
  kwargs:
    batch_size: 32
    batch_size_head: 256
    dataset: uci
    device: cuda
    epochs_head: 300
    input_shape:
    - 60
    - 6
    lr: 0.001
    min_delta: 0.001
    n_components: 60
    patience: 10
    save_model: false
    save_reducer: false
    temperature_head: 0.1
    total_epochs: 50
    transform_funcs: [0]
    verbose: 0
    
  name: SimCLR_full
  use_y: true
reducer_dataset:
- uci.standartized_balanced[train]
test_dataset:
- uci.standartized_balanced[validation]
train_dataset:
- uci.standartized_balanced[train]
version: '1.0'

    """
    transform = config['transform_funcs'].replace('(','[')
    transform = transform.replace(')',']')
    config_data = data.replace('transform_funcs: [0]',f'transform_funcs: {transform}')
    config_data = config_data.replace('uci',f'{dataset}')

    with open(f'{folder}/base_config.yaml', 'w') as file:
            file.write(config_data)

def create_exploration_config_simclr_full_best(folder,latent_dim):
    data= """
    resources:
      gpu: 0.9
      cpu: 1.0
    search_space: 
    
      min_delta:
        tune_function: quniform
        tune_parameters: [0.001, 0.9,0.001]
        route: reducer/kwargs/min_delta
    
      temperature_head:
        tune_function: quniform
        tune_parameters: [0.1, 1.0,0.1]
        route: reducer/kwargs/temperature_head
 
      batch_size:
        tune_function: randint
        tune_parameters: [128, 512]
        route: reducer/kwargs/batch_size
    
      latent_dim:
        tune_function: randint
        tune_parameters: [2, 361]
        route: reducer/kwargs/n_components
    
    initial_params:
    
    """
    dim=str((latent_dim*360/100)+1)
    config_data = data.replace('tune_parameters: [2, 361]',f'tune_parameters: [2,{dim}]')
    with open(f'{folder}/exploration_config.yaml', 'w') as file:
        file.write(config_data)


def create_simclr_linear_basic_best(dataset,folder,config):
    data="""
estimators:
- algorithm: RandomForest
  kwargs:
    n_estimators: 100
  name: randomforest-100
  num_runs: 10
- algorithm: KNN
  kwargs:
    n_neighbors: 5
  name: KNN-5
  num_runs: 1
- algorithm: SVM
  kwargs:
    C: 1.0
    kernel: rbf
  name: SVM-rbf-C1.0
  num_runs: 1
extra:
  in_use_features:
  - accel-x
  - accel-y
  - accel-z
  - gyro-x
  - gyro-y
  - gyro-z
  reduce_on: all
  save_reducer: false
  scale_on: train
reducer:
  algorithm: SimCLR_linear
  kwargs:
    batch_size: 32
    batch_size_head: 256
    dataset: uci
    device: cuda
    epochs_head: 300
    input_shape:
    - 60
    - 6
    lr: 0.001
    min_delta: 0.001
    n_components: 60
    patience: 10
    save_model: false
    save_reducer: false
    temperature_head: 0.1
    total_epochs: 50
    transform_funcs: [0]
    verbose: 0
    
  name: SimCLR_linear
  use_y: true
reducer_dataset:
- uci.standartized_balanced[train]
test_dataset:
- uci.standartized_balanced[validation]
train_dataset:
- uci.standartized_balanced[train]
version: '1.0'

    """
    transform = config['transform_funcs'].replace('(','[')
    transform = transform.replace(')',']')
    config_data = data.replace('transform_funcs: [0]',f'transform_funcs: {transform}')
    config_data = config_data.replace('uci',f'{dataset}')

    with open(f'{folder}/base_config.yaml', 'w') as file:
            file.write(config_data)

def create_exploration_config_simclr_linear_best(folder,latent_dim):
    data= """
    resources:
      gpu: 0.9
      cpu: 1.0
    search_space: 
    
      min_delta:
        tune_function: quniform
        tune_parameters: [0.001, 0.9,0.001]
        route: reducer/kwargs/min_delta
    
      temperature_head:
        tune_function: quniform
        tune_parameters: [0.1, 1.0,0.1]
        route: reducer/kwargs/temperature_head
 
      batch_size:
        tune_function: randint
        tune_parameters: [128, 512]
        route: reducer/kwargs/batch_size
    
      latent_dim:
        tune_function: randint
        tune_parameters: [2, 361]
        route: reducer/kwargs/n_components
    
    initial_params:
    
    """
    dim=str((latent_dim*360/100)+1)
    config_data = data.replace('tune_parameters: [2, 361]',f'tune_parameters: [2,{dim}]')
    with open(f'{folder}/exploration_config.yaml', 'w') as file:
        file.write(config_data)



def create_best_config_all_datasets():
    datasets = ['kuhar', 'motionsense',  'wisdm', 'realworld_thigh', 'realworld_waist']
    for dataset in datasets:
        filtered_data_brackets = combined_data[combined_data['dataset'] == dataset]['score'].idxmax()
        
        print(filtered_data_brackets['dataset'],filtered_data_brackets['score'])

# %%
def read_base_config(ruta_archivo,config_column):
    try:
        
        with open(ruta_archivo, 'r') as archivo:
            datos_yaml = yaml.safe_load(archivo)
      
        value = datos_yaml['reducer']['kwargs'][config_column]
    except:
        print("error")
        value=-1
    return value


def get_row_max_by_dataset():
    idx_max = combined_data.groupby(['dataset'])['score'].idxmax()
    fmax_score = combined_data.loc[idx_max]    
    return fmax_score
max=get_row_max_by_dataset()
config_columns = max.filter(like='config/').columns.tolist()
print(config_columns)

def create_best_simclr_config_exploration():
    config={}
    for index, row in df_fmax_score.iterrows():
        dataset=row['dataset']
        for config_column in config_columns:    
            config[config_column.split('/')[1]]=row[config_column]
            config['percentage']=row['percentage'] 
            dir= row['dir']
            model=row['model']
            percentage=row['percentage']
            if pd.isna(row[config_column]):
                file=f'../{dir}/{dataset}/{model}_{dataset}_P{percentage}/base_config.yaml'
                config[config_column.split('/')[1]]=read_base_config(file,config_column.split('/')[1])
        
        new_folder=f'../experiments/simclr_all1/all_transformations/{model}/best/{dataset}/{model}_{dataset}_P{percentage}'
        #print(dataset,config)
        print(new_folder)
        create_folder(new_folder)
        create_exploration_config_simclr_best(new_folder,percentage)
        create_simclr_basic_best(dataset,new_folder,config)
       
    
    
#create_best_simclr_config_exploration()
# Out:
# ['config/temperature_head', 'config/latent_dim', 'config/transform_funcs', 'config/batch_size']

# %%
def read_base_config(ruta_archivo,config_column):
    try:
        
        with open(ruta_archivo, 'r') as archivo:
            datos_yaml = yaml.safe_load(archivo)
      
        value = datos_yaml['reducer']['kwargs'][config_column]
    except:
        print("error")
        value=-1
    return value


def get_row_max_by_dataset():
    idx_max = combined_data.groupby(['dataset'])['score'].idxmax()
    fmax_score = combined_data.loc[idx_max]    
    return fmax_score
max=get_row_max_by_dataset()
config_columns = max.filter(like='config/').columns.tolist()
print(config_columns)

def create_best_simclr_full_config_exploration():
    config={}
    for index, row in df_fmax_score.iterrows():
        dataset=row['dataset']
        for config_column in config_columns:    
            config[config_column.split('/')[1]]=row[config_column]
            config['percentage']=row['percentage'] 
            dir= row['dir']
            model=row['model']
            percentage=row['percentage']
            if pd.isna(row[config_column]):
                file=f'../{dir}/{dataset}/{model}_{dataset}_P{percentage}/base_config.yaml'
                config[config_column.split('/')[1]]=read_base_config(file,config_column.split('/')[1])
            print(config[config_column.split('/')[1]])
        new_folder=f'../experiments/simclr_all1/all_transformations/{model}/best/{dataset}/{model}_{dataset}_P{percentage}'
        #print(dataset,config)
        print(new_folder)
        create_folder(new_folder)
        create_exploration_config_simclr_full_best(new_folder,percentage)
        create_simclr_full_basic_best(dataset,new_folder,config)
       
    
    

#create_best_simclr_full_config_exploration()
# Out:
# ['config/temperature_head', 'config/latent_dim', 'config/transform_funcs', 'config/batch_size']
# 0.1
# 54
# (1, 2, 4)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/kuhar/simclr_full_kuhar_P25
# 0.1
# 67
# (0, 1, 2, 3)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/kuhar/simclr_full_kuhar_P50
# 0.1
# 66
# (2, 5, 9)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/kuhar/simclr_full_kuhar_P75
# 0.1
# 95
# (1, 2, 4)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/kuhar/simclr_full_kuhar_P100
# 1.0
# 208
# (0, 1, 5, 9)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/kuhar/simclr_full_kuhar_P200
# 0.1
# 49
# (0, 3, 8, 11)
# 233
# ../experiments/simclr_all1/all_transformations/simclr_full/best/motionsense/simclr_full_motionsense_P25
# 0.3
# 163
# (6,)
# 318
# ../experiments/simclr_all1/all_transformations/simclr_full/best/motionsense/simclr_full_motionsense_P50
# 0.1
# 30
# (0, 5)
# 393
# ../experiments/simclr_all1/all_transformations/simclr_full/best/motionsense/simclr_full_motionsense_P75
# 0.1
# 37
# (1, 8, 9, 11)
# 447
# ../experiments/simclr_all1/all_transformations/simclr_full/best/motionsense/simclr_full_motionsense_P100
# 0.1
# 296
# (2, 4, 8)
# 490
# ../experiments/simclr_all1/all_transformations/simclr_full/best/motionsense/simclr_full_motionsense_P200
# 1.0
# 13
# (3, 4, 6, 8)
# 305
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_thigh/simclr_full_realworld_thigh_P25
# 0.3
# 144
# (0, 2, 4, 8)
# 478
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_thigh/simclr_full_realworld_thigh_P50
# 0.7000000000000001
# 18
# (4, 6)
# 414
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_thigh/simclr_full_realworld_thigh_P75
# 0.5
# 240
# (2,)
# 359
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_thigh/simclr_full_realworld_thigh_P100
# 1.0
# 30
# (2, 6, 8, 10)
# 377
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_thigh/simclr_full_realworld_thigh_P200
# 0.2
# 84
# (1, 2, 6, 11)
# 187
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_waist/simclr_full_realworld_waist_P25
# 0.1
# 36
# (2,)
# 193
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_waist/simclr_full_realworld_waist_P50
# 0.2
# 156
# (1, 2)
# 425
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_waist/simclr_full_realworld_waist_P75
# 0.2
# 243
# (2, 5, 9)
# 128
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_waist/simclr_full_realworld_waist_P100
# 0.3
# 352
# (1, 2, 6)
# 270
# ../experiments/simclr_all1/all_transformations/simclr_full/best/realworld_waist/simclr_full_realworld_waist_P200
# 0.3
# 15
# (1, 4, 10, 11)
# 140
# ../experiments/simclr_all1/all_transformations/simclr_full/best/uci/simclr_full_uci_P25
# 0.6000000000000001
# 57
# (2, 6, 10, 11)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/uci/simclr_full_uci_P50
# 0.1
# 234
# (1, 2, 6)
# 178
# ../experiments/simclr_all1/all_transformations/simclr_full/best/uci/simclr_full_uci_P75
# 0.6000000000000001
# 179
# (0, 4, 8, 11)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/uci/simclr_full_uci_P100
# 0.9
# 396
# (1, 6)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/uci/simclr_full_uci_P200
# 0.4
# 51
# (3,)
# 477
# ../experiments/simclr_all1/all_transformations/simclr_full/best/wisdm/simclr_full_wisdm_P25
# 0.4
# 102
# (7,)
# 458
# ../experiments/simclr_all1/all_transformations/simclr_full/best/wisdm/simclr_full_wisdm_P50
# 0.7000000000000001
# 224
# (0,)
# 240
# ../experiments/simclr_all1/all_transformations/simclr_full/best/wisdm/simclr_full_wisdm_P75
# 0.7000000000000001
# 187
# (8,)
# 384
# ../experiments/simclr_all1/all_transformations/simclr_full/best/wisdm/simclr_full_wisdm_P100
# 0.5
# 273
# (1, 4, 9, 10)
# 32
# ../experiments/simclr_all1/all_transformations/simclr_full/best/wisdm/simclr_full_wisdm_P200

# %%
def read_base_config(ruta_archivo,config_column):
    try:
        
        with open(ruta_archivo, 'r') as archivo:
            datos_yaml = yaml.safe_load(archivo)
      
        value = datos_yaml['reducer']['kwargs'][config_column]
    except:
        print("error")
        value=-1
    return value


def get_row_max_by_dataset():
    idx_max = combined_data.groupby(['dataset'])['score'].idxmax()
    fmax_score = combined_data.loc[idx_max]    
    return fmax_score
max=get_row_max_by_dataset()
config_columns = max.filter(like='config/').columns.tolist()
print(config_columns)

def create_best_simclr_linear_config_exploration():
    config={}
    for index, row in df_fmax_score.iterrows():
        dataset=row['dataset']
        for config_column in config_columns:    
            config[config_column.split('/')[1]]=row[config_column]
            config['percentage']=row['percentage'] 
            dir= row['dir']
            model=row['model']
            percentage=row['percentage']
            if pd.isna(row[config_column]):
                file=f'../{dir}/{dataset}/{model}_{dataset}_P{percentage}/base_config.yaml'
                config[config_column.split('/')[1]]=read_base_config(file,config_column.split('/')[1])
            print(config[config_column.split('/')[1]])
        new_folder=f'../experiments/simclr_all1/all_transformations/{model}/best/{dataset}/{model}_{dataset}_P{percentage}'
        #print(dataset,config)
        print(new_folder)
        create_folder(new_folder)
        create_exploration_config_simclr_linear_best(new_folder,percentage)
        create_simclr_linear_basic_best(dataset,new_folder,config)
       
    
    

create_best_simclr_linear_config_exploration()

# %%
maximos_por_grupo = df_all_best.groupby(['dataset','model'])['score'].max()
maximos_por_grupo
# Out:
# dataset          model
# kuhar            simclr_full    0.748357
# motionsense      simclr_full    0.892381
# realworld_thigh  simclr_full     0.79932
# realworld_waist  simclr_full     0.89644
# uci              simclr_full    0.909412
# wisdm            simclr_full         0.0
# Name: score, dtype: object
